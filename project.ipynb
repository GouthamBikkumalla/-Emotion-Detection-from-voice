# %%
pip install tensorflow

# %%
## Don't change anything in this cell.
from sklearn.datasets import fetch_covtype
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
forests = fetch_covtype()
X = forests.data
Y = forests.target
Y = Y-1
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.60, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from tensorflow import keras


model = keras.models.Sequential([
        keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
        keras.layers.Dense(7, activation="softmax")
    ])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])


history = model.fit(X_train_scaled, Y_train, epochs=20)

print("Evaluating on Test Set:")
predictions = model.evaluate(X_test_scaled, Y_test)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.6545 - accuracy: 0.7240
# Epoch 2/20
# 7263/7263 [==============================] - 15s 2ms/step - loss: 0.5701 - accuracy: 0.7559
# Epoch 3/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5503 - accuracy: 0.7631
# Epoch 4/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5371 - accuracy: 0.7694
# Epoch 5/20
# 7263/7263 [==============================] - 15s 2ms/step - loss: 0.5281 - accuracy: 0.7734
# Epoch 6/20
# 7263/7263 [==============================] - 15s 2ms/step - loss: 0.5210 - accuracy: 0.7773
# Epoch 7/20
# 7263/7263 [==============================] - 15s 2ms/step - loss: 0.5159 - accuracy: 0.7787
# Epoch 8/20
# 7263/7263 [==============================] - 15s 2ms/step - loss: 0.5110 - accuracy: 0.7816
# Epoch 9/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5069 - accuracy: 0.7833
# Epoch 10/20
# ...

# %%
# Network 1
model1 = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(7, activation="softmax")
])

model1.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])

history1 = model1.fit(X_train_scaled, Y_train, epochs=20)

# Network 2
model2 = keras.models.Sequential([
    keras.layers.Dense(100, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(50, activation="relu"),
    keras.layers.Dense(10, activation="relu"),
    keras.layers.Dense(7, activation="softmax")
])

model2.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])

print("Evaluating on Test Set:")
history2 = model2.fit(X_train_scaled, Y_train, epochs=20)

# # Network 3
# model3 = keras.models.Sequential([
#     keras.layers.Dense(10, activation="relu", input_shape=X_train.shape[1:]),
#     keras.layers.Dense(7, activation="softmax")
# ])

# model3.compile(loss="sparse_categorical_crossentropy",
#               optimizer="Adam",
#               metrics=["accuracy"])

# history3 = model3.fit(X_train_scaled, Y_train, epochs=20)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 17s 2ms/step - loss: 0.6537 - accuracy: 0.7246
# Epoch 2/20
# 7263/7263 [==============================] - 17s 2ms/step - loss: 0.5663 - accuracy: 0.7571
# Epoch 3/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5431 - accuracy: 0.7656
# Epoch 4/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5305 - accuracy: 0.7703
# Epoch 5/20
# 7263/7263 [==============================] - 17s 2ms/step - loss: 0.5219 - accuracy: 0.7739
# Epoch 6/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.5149 - accuracy: 0.7783
# Epoch 7/20
# 7263/7263 [==============================] - 23s 3ms/step - loss: 0.5090 - accuracy: 0.7804
# Epoch 8/20
# 7263/7263 [==============================] - 17s 2ms/step - loss: 0.5042 - accuracy: 0.7822
# Epoch 9/20
# 7263/7263 [==============================] - 15s 2ms/step - loss: 0.4999 - accuracy: 0.7855
# Epoch 10/20
# ...

# %%
from tensorflow import keras


model = keras.models.Sequential([
        keras.layers.Dense(100, activation="relu", input_shape=X_train.shape[1:]),
        keras.layers.Dense(50, activation="relu"),
        keras.layers.Dense(10, activation="relu"),
        keras.layers.Dense(7, activation="softmax")
    ])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])


history = model.fit(X_train_scaled, Y_train, epochs=20)

print("Evaluating on Test Set:")
predictions = model.evaluate(X_test_scaled, Y_test)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 22s 3ms/step - loss: 0.5786 - accuracy: 0.7517
# Epoch 2/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4767 - accuracy: 0.7966
# Epoch 3/20
# 7263/7263 [==============================] - 18s 2ms/step - loss: 0.4335 - accuracy: 0.8170
# Epoch 4/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4053 - accuracy: 0.8302
# Epoch 5/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3848 - accuracy: 0.8395
# Epoch 6/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3704 - accuracy: 0.8459
# Epoch 7/20
# 7263/7263 [==============================] - 18s 2ms/step - loss: 0.3572 - accuracy: 0.8518
# Epoch 8/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3476 - accuracy: 0.8567
# Epoch 9/20
# 7263/7263 [==============================] - 18s 2ms/step - loss: 0.3391 - accuracy: 0.8605
# Epoch 10/20
# ...

# %%
from tensorflow import keras


model = keras.models.Sequential([
        keras.layers.Dense(100, activation="sigmoid", kernel_initializer='random_uniform', input_shape=X_train.shape[1:]),
        keras.layers.Dense(50, activation="sigmoid"),
        keras.layers.Dense(10, activation="sigmoid"),
        keras.layers.Dense(7, activation="softmax")
    ])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])


history = model.fit(X_train_scaled, Y_train, epochs=20)

print("Evaluating on Test Set:")
predictions = model.evaluate(X_test_scaled, Y_test)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 24s 3ms/step - loss: 0.7301 - accuracy: 0.7004
# Epoch 2/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.6193 - accuracy: 0.7383
# Epoch 3/20
# 7263/7263 [==============================] - 20s 3ms/step - loss: 0.5693 - accuracy: 0.7597
# Epoch 4/20
# 7263/7263 [==============================] - 18s 3ms/step - loss: 0.5239 - accuracy: 0.7791
# Epoch 5/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4870 - accuracy: 0.7935
# Epoch 6/20
# 7263/7263 [==============================] - 18s 3ms/step - loss: 0.4586 - accuracy: 0.8075
# Epoch 7/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4346 - accuracy: 0.8184
# Epoch 8/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4153 - accuracy: 0.8281
# Epoch 9/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3990 - accuracy: 0.8355
# Epoch 10/20
# ...

# %%
from tensorflow import keras


model = keras.models.Sequential([
        keras.layers.Dense(100, activation="tanh", kernel_initializer='random_normal', input_shape=X_train.shape[1:]),
        keras.layers.Dense(50, activation="tanh"),
        keras.layers.Dense(10, activation="tanh"),
        keras.layers.Dense(7, activation="softmax")
    ])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])


history = model.fit(X_train_scaled, Y_train, epochs=20)

print("Evaluating on Test Set:")
predictions = model.evaluate(X_test_scaled, Y_test)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 20s 3ms/step - loss: 0.6005 - accuracy: 0.7510
# Epoch 2/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4687 - accuracy: 0.8050
# Epoch 3/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4093 - accuracy: 0.8332
# Epoch 4/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3738 - accuracy: 0.8497
# Epoch 5/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3509 - accuracy: 0.8600
# Epoch 6/20
# 7263/7263 [==============================] - 18s 3ms/step - loss: 0.3329 - accuracy: 0.8683
# Epoch 7/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3190 - accuracy: 0.8735
# Epoch 8/20
# 7263/7263 [==============================] - 18s 3ms/step - loss: 0.3068 - accuracy: 0.8799
# Epoch 9/20
# 7263/7263 [==============================] - 20s 3ms/step - loss: 0.2974 - accuracy: 0.8831
# Epoch 10/20
# ...

# %%
from tensorflow import keras


model = keras.models.Sequential([
        keras.layers.Dense(100, kernel_initializer='he_normal', input_shape=X_train.shape[1:]),
        keras.layers.LeakyReLU(alpha = 0.1),
        keras.layers.Dense(50),
        keras.layers.LeakyReLU(alpha = 0.1),
        keras.layers.Dense(10),
        keras.layers.LeakyReLU(alpha = 0.1),
        keras.layers.Dense(7, activation="softmax")
    ])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])


history = model.fit(X_train_scaled, Y_train, epochs=20)

print("Evaluating on Test Set:")
predictions = model.evaluate(X_test_scaled, Y_test)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 20s 3ms/step - loss: 0.5931 - accuracy: 0.7520
# Epoch 2/20
# 7263/7263 [==============================] - 18s 3ms/step - loss: 0.4879 - accuracy: 0.7918
# Epoch 3/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4487 - accuracy: 0.8108
# Epoch 4/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.4219 - accuracy: 0.8232
# Epoch 5/20
# 7263/7263 [==============================] - 20s 3ms/step - loss: 0.4028 - accuracy: 0.8315
# Epoch 6/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3880 - accuracy: 0.8383
# Epoch 7/20
# 7263/7263 [==============================] - 20s 3ms/step - loss: 0.3769 - accuracy: 0.8439
# Epoch 8/20
# 7263/7263 [==============================] - 18s 3ms/step - loss: 0.3672 - accuracy: 0.8476
# Epoch 9/20
# 7263/7263 [==============================] - 19s 3ms/step - loss: 0.3590 - accuracy: 0.8515
# Epoch 10/20
# ...

# %%
from tensorflow import keras


model = keras.models.Sequential([
        keras.layers.Dense(100, kernel_initializer='random_normal', input_shape=X_train.shape[1:]),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("tanh"),
        keras.layers.Dense(50),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("tanh"),
        keras.layers.Dense(10),
        keras.layers.BatchNormalization(),
        keras.layers.Activation("tanh"),
        keras.layers.Dense(7, activation="softmax")
    ])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])


history = model.fit(X_train_scaled, Y_train, epochs=20)

print("Evaluating on Test Set:")
predictions = model.evaluate(X_test_scaled, Y_test)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 27s 4ms/step - loss: 0.6433 - accuracy: 0.7374
# Epoch 2/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.5230 - accuracy: 0.7790
# Epoch 3/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.4893 - accuracy: 0.7933
# Epoch 4/20
# 7263/7263 [==============================] - 25s 4ms/step - loss: 0.4697 - accuracy: 0.8021
# Epoch 5/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.4556 - accuracy: 0.8080
# Epoch 6/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.4448 - accuracy: 0.8124
# Epoch 7/20
# 7263/7263 [==============================] - 25s 3ms/step - loss: 0.4373 - accuracy: 0.8157
# Epoch 8/20
# 7263/7263 [==============================] - 25s 3ms/step - loss: 0.4301 - accuracy: 0.8191
# Epoch 9/20
# 7263/7263 [==============================] - 25s 3ms/step - loss: 0.4264 - accuracy: 0.8205
# Epoch 10/20
# ...

# %%
from tensorflow import keras


model = keras.models.Sequential([
        keras.layers.Dense(100, kernel_initializer='random_normal', input_shape=X_train.shape[1:]),
        keras.layers.Activation("tanh"),
        keras.layers.BatchNormalization(),
        keras.layers.Dense(50),
        keras.layers.Activation("tanh"),
        keras.layers.BatchNormalization(),
        keras.layers.Dense(10),
        keras.layers.Activation("tanh"),
        keras.layers.BatchNormalization(),
        keras.layers.Dense(7, activation="softmax")
    ])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])


history = model.fit(X_train_scaled, Y_train, epochs=20)

print("Evaluating on Test Set:")
predictions = model.evaluate(X_test_scaled, Y_test)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 28s 4ms/step - loss: 0.6395 - accuracy: 0.7369
# Epoch 2/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.5354 - accuracy: 0.7728
# Epoch 3/20
# 7263/7263 [==============================] - 25s 3ms/step - loss: 0.5028 - accuracy: 0.7880
# Epoch 4/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.4782 - accuracy: 0.7987
# Epoch 5/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.4595 - accuracy: 0.8073
# Epoch 6/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.4426 - accuracy: 0.8161
# Epoch 7/20
# 7263/7263 [==============================] - 25s 4ms/step - loss: 0.4313 - accuracy: 0.8201
# Epoch 8/20
# 7263/7263 [==============================] - 25s 3ms/step - loss: 0.4211 - accuracy: 0.8248
# Epoch 9/20
# 7263/7263 [==============================] - 26s 4ms/step - loss: 0.4105 - accuracy: 0.8310
# Epoch 10/20
# ...

# %%
# Experiment 1: Sigmoid activation with Xavier initialization
model4 = keras.models.Sequential([
    keras.layers.Dense(30, activation="sigmoid", kernel_initializer="glorot_uniform", input_shape=X_train.shape[1:]),
    keras.layers.Dense(7, activation="softmax")
])

model4.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])

history4 = model4.fit(X_train_scaled, Y_train, epochs=20)

# Experiment 2: ReLU activation with He initialization
model5 = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", kernel_initializer="he_normal", input_shape=X_train.shape[1:]),
    keras.layers.Dense(7, activation="softmax")
])

model5.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])

history5 = model5.fit(X_train_scaled, Y_train, epochs=20)

# Experiment 3: Tanh activation with random normal initialization
model6 = keras.models.Sequential([
    keras.layers.Dense(30, activation="tanh", kernel_initializer="random_normal", input_shape=X_train.shape[1:]),
    keras.layers.Dense(7, activation="softmax")
])

model6.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])

history6 = model6.fit(X_train_scaled, Y_train, epochs=20)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 34s 4ms/step - loss: 0.6878 - accuracy: 0.7105
# Epoch 2/20
# 7263/7263 [==============================] - 15s 2ms/step - loss: 0.5979 - accuracy: 0.7419
# Epoch 3/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5691 - accuracy: 0.7558
# Epoch 4/20
# 7263/7263 [==============================] - 15s 2ms/step - loss: 0.5479 - accuracy: 0.7656
# Epoch 5/20
# 7263/7263 [==============================] - 17s 2ms/step - loss: 0.5317 - accuracy: 0.7728
# Epoch 6/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5189 - accuracy: 0.7792
# Epoch 7/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5086 - accuracy: 0.7842
# Epoch 8/20
# 7263/7263 [==============================] - 16s 2ms/step - loss: 0.5003 - accuracy: 0.7870
# Epoch 9/20
# 7263/7263 [==============================] - 17s 2ms/step - loss: 0.4935 - accuracy: 0.7900
# Epoch 10/20
# ...

# %%
model2 = keras.models.Sequential([
    keras.layers.Dense(100, activation="sigmoid", input_shape=X_train.shape[1:]),
    keras.layers.Dense(50, activation="sigmoid"),
    keras.layers.Dense(10, activation="sigmoid"),
    keras.layers.Dense(7, activation="softmax")
])

model2.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])

history2 = model2.fit(X_train_scaled, Y_train, epochs=20)

# %%
# Network 2 with batch normalization before activation
model2_bn_before = keras.models.Sequential([
    keras.layers.Dense(100, input_shape=X_train.shape[1:]),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("relu"),
    keras.layers.Dense(50),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("relu"),
    keras.layers.Dense(7, activation="softmax")
])

model2_bn_before.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])

history2_bn_before = model2_bn_before.fit(X_train_scaled, Y_train, epochs=20)

# Network 2 with batch normalization after activation
model2_bn_after = keras.models.Sequential([
    keras.layers.Dense(100, input_shape=X_train.shape[1:]),
    keras.layers.Activation("relu"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(50),
    keras.layers.Activation("relu"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(7, activation="softmax")
])

model2_bn_after.compile(loss="sparse_categorical_crossentropy",
              optimizer="Adam",
              metrics=["accuracy"])

history2_bn_after = model2_bn_after.fit(X_train_scaled, Y_train, epochs=20)
# Out:
# Epoch 1/20
# 7263/7263 [==============================] - 24s 3ms/step - loss: 0.6081 - accuracy: 0.7416
# Epoch 2/20
# 7263/7263 [==============================] - 24s 3ms/step - loss: 0.5230 - accuracy: 0.7742
# Epoch 3/20
# 7263/7263 [==============================] - 22s 3ms/step - loss: 0.4939 - accuracy: 0.7873
# Epoch 4/20
# 7263/7263 [==============================] - 22s 3ms/step - loss: 0.4772 - accuracy: 0.7945
# Epoch 5/20
# 7263/7263 [==============================] - 22s 3ms/step - loss: 0.4630 - accuracy: 0.8014
# Epoch 6/20
# 7263/7263 [==============================] - 21s 3ms/step - loss: 0.4556 - accuracy: 0.8047
# Epoch 7/20
# 7263/7263 [==============================] - 22s 3ms/step - loss: 0.4471 - accuracy: 0.8097
# Epoch 8/20
# 7263/7263 [==============================] - 22s 3ms/step - loss: 0.4404 - accuracy: 0.8129
# Epoch 9/20
# 7263/7263 [==============================] - 21s 3ms/step - loss: 0.4364 - accuracy: 0.8142
# Epoch 10/20
# ...
